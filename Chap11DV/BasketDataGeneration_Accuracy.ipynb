# %% [markdown]
# # Generate Basket Data

# %%
from BasketDataGen import value_basket, generate_basket_data_impl, generate_basket_data
import numpy as np
import QuantLib as ql
import time

# %% [markdown]
# ## Example price

# %%
mc_samples_size = [1000,10000,100000]

# %%
idname = 1
samples = 1
stock_mean = 0.5
stock_vol = 0.2
b1 = 5 
b2 = 2
basket_size = 6

# %%
threads = 1
samples = 100
filename = 'test_basket_accuracy_time'

# %%
start_time = time.time()
generate_basket_data(threads, samples, filename, mc_samples_size, stock_mean, stock_vol, b1, b2, basket_size)
end_time = time.time()

# %%
print(end_time - start_time)

# %%
5000*(end_time - start_time) / 60 / 60 /24
